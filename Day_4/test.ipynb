# %%
import math_local

# %%
math_local.root(23)
# Out:
# The value of x for 0 iteration is 23
# ...
# The value of x for 0 iteration is 15.335373500745526
# ...
# The value of x for 1 iteration is 10.230837016579425
# ...
# The value of x for 2 iteration is 6.8257678014645276
# ...
# The value of x for 3 iteration is 4.540202613927622
# ...
# The value of x for 4 iteration is 3.015095697152492
# ...
# The value of x for 5 iteration is 2.0498014485142755
# ...
# The value of x for 6 iteration is 1.458557376137892
# ...
# The value of x for 7 iteration is 1.1221688021803886
# ...
# The value of x for 8 iteration is 0.9690428584949248
# ...
# The value of x for 9 iteration is 0.9310028640091709
# ...
# The value of x for 10 iteration is 0.9286353068570367
# ...
# The value of x for 11 iteration is 0.9286263088614938
# ...
# The value of x for 12 iteration is 0.9286263087317345
# The root is 0.9286263087317345
# (np.float64(0.9286263087317345), 13)

# %%
math_local.fx(0.9286263087317345)
# Out:
# np.float64(0.0)
