# %%
print(3232312)
# Out:
# 3232312

# %%
print("Hello all guys")
# Out:
# Hello all guys

# %%
print(hello all guys)
# Out:
#   Cell In[3], line 1
#     print(hello all guys)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("a")
# Out:
# a

# %%
print(0.4534)
# Out:
# 0.4534

# %%
print(34343.45)
# Out:
# 34343.45

# %%
print('hello')
# Out:
# hello

# %%
print("hello")
# Out:
# hello

# %% [markdown]
# ### Data Types
#
#     1. Integer: 3,4,5,6
#     2. float: 32.2,0.89, 1000.0
#     3. string: collection of characters: alphabets, special@#!(),., 322323 that will be enclosed in "" or ''
#     4. boolean: True, False

# %%
454
# Out:
# 454

# %%
type(454)
# Out:
# int

# %%
type(454.0)
# Out:
# float

# %%
type("454.0")
# Out:
# str

# %%
type(3>2)
# Out:
# bool

# %%
3>2
# Out:
# True

# %% [markdown]
# ### Mathematical operations

# %%
3+2
# Out:
# 5

# %%
3-2
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
3/2
# Out:
# 1.5

# %%
4/2
# Out:
# 2.0

# %%
5**3
# Out:
# 125

# %%
print(4*2)
print(4**2)
# Out:
# 8
# 16

# %%
5/3
# Out:
# 1.6666666666666667

# %%
5//3
# Out:
# 1

# %%
5/2
# Out:
# 2.5

# %%
5%2
# Out:
# 1

# %%
23%4
# Out:
# 3

# %%
## Math for strings

# %%
"hello " + "all "
# Out:
# 'hello all '

# %%
"hello" * 3 #"hello" + "hello" +"hello"
# Out:
# 'hellohellohello'

# %%
print(4*3)
print(2*"3")
# Out:
# 12
# 33

# %%
"hello"/"o"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 "hello"/"o"
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
78>2
# Out:
# True

# %%
43<45
# Out:
# True

# %%
98<1
# Out:
# False

# %%
2==3
# Out:
# False

# %%
2!=3
# Out:
# True

# %%
2!=2
# Out:
# False

# %%
32>102 and 1>2
# Out:
# False

# %%
32>12 or 1>2
# Out:
# True

# %%
32>122 or 1>22
# Out:
# False

# %% [markdown]
# ## Variable: containers for storing values
#
#     - vatiable is created the moment you first assign a value to is using = sign
#     - hold the data in runtime

# %%
porosity = 0.678239876543879234

# %%
porosity
# Out:
# 0.6782398765438792

# %%
print(porosity)
# Out:
# 0.6782398765438792

# %%
print("porosity")
# Out:
# porosity

# %%
a =2

# %%
print(a)
# Out:
# 2

# %%
p = porosity

# %%
print(p)
# Out:
# 0.6782398765438792

# %%
p = "permeability"

# %%
print(p)
# Out:
# permeability

# %%
a= 3
b= 6
a = b+2 #a = 8
b = a+3 # b = 11

print(a+b) #8+11
# Out:
# 19

# %%
a
# Out:
# 8

# %%
a==9
# Out:
# False

# %% [markdown]
# ## Variable names: cannot start with number or specail character, it can start alphabet or _
#
# ## can't have spaces b/w two characters, underscore is allowed

# %%
1a = 92
# Out:
#   Cell In[71], line 1
#     1a = 92
#     ^
# SyntaxError: invalid decimal literal

# %%
a1 = 92

# %%
a1
# Out:
# 92

# %%
_p = 1

# %%
@p = 1
# Out:
#   Cell In[75], line 1
#     @p = 1
#      ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
p1 = 1
p_2 =2
p_3 = 3

# %% [markdown]
# ## input : taking input from user

# %%
porosity = input()

# %%
porosity
# Out:
# '23'

# %%
porosity = float(input())

# %%
porosity
# Out:
# 54.0

# %%
porosity = float(input("Enter the porosity of reservoir in fractions: "))

# %%
porosity
# Out:
# 0.65

# %%
porosity = porosity*100

# %%
print(porosity)
# Out:
# 65.0

# %%
porosity = float(input("Enter the porosity of reservoir in fractions: "))
permeability = float(input('Enter the formation\'s permeability(md): '))
print(f"Porosity value is {porosity}, and permeability values is {permeability}")
# Out:
# Porosity value is 0.32, and permeability values is 21.0

# %%
print(permeability)
print(porosity)
# Out:
# 21.0
# 0.32

# %%
print(f"Porosity value is {porosity}, and permeability values is {permeability}")
# Out:
# Porosity value is 0.32, and permeability values is 21.0

# %% [markdown]
# ## Data Structure: holding and processing large quantities of Data
#
# 1. Lists
#     - Used to store multiple data points in a signle variable
#     - [] or list
#     - Mutable: can change the length, elements and elements values
#     - Hold any data, str, int, float, bool, list, list of list

# %%
poro = [0.32,0.43,0.12]

# %%
poro
# Out:
# [0.32, 0.43, 0.12]

# %%
type(poro)
# Out:
# list

# %%
li = [2323,45.0,0.43423, "helloo engineers", True, ["hello",3,False]]

# %%
li
# Out:
# [2323, 45.0, 0.43423, 'helloo engineers', True, ['hello', 3, False]]

# %%
poro
# Out:
# [0.32, 0.43, 0.12]

# %%
porosity = [0.3,0.41,0.51,0.11,0.34,0.67]

# %%
len(porosity)
# Out:
# 6

# %%
li
# Out:
# [2323, 45.0, 0.43423, 'helloo engineers', True, ['hello', 3, False]]

# %%
len(li)
# Out:
# 6

# %%
porosity
# Out:
# [0.3, 0.41, 0.51, 0.11, 0.34, 0.67]

# %%
#index =Address of element inside the datastructure

# %%
porosity[2]
# Out:
# 0.51

# %%
porosity[4]
# Out:
# 0.34

# %%
porosity[-1]
# Out:
# 0.67

# %%
porosity[5]
# Out:
# 0.67

# %%
porosity[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[114], line 1
# ----> 1 porosity[7]
#
# IndexError: list index out of range

# %%
#Mutable

# %%
porosity
# Out:
# [0.3, 0.41, 0.51, 0.11, 0.34, 0.67]

# %%
porosity[4] = 0.43

# %%
porosity
# Out:
# [0.3, 0.41, 0.51, 0.11, 0.43, 0.67]

# %%
#accessing more thaan one data point: slicing
# list_name[starting_index:stopping_index:step]
#stopping index element will not be included in the slice

# %%
porosity
# Out:
# [0.3, 0.41, 0.51, 0.11, 0.43, 0.67]

# %%
porosity[2:5]
# Out:
# [0.51, 0.11, 0.43]

# %%
porosity[:3]
# Out:
# [0.3, 0.41, 0.51]

# %%
porosity[3:]
# Out:
# [0.11, 0.43, 0.67]

# %%
porosity[1::2]
# Out:
# [0.41, 0.11, 0.67]

# %%
li
# Out:
# [2323, 45.0, 0.43423, 'helloo engineers', True, ['hello', 3, False]]

# %%
li[-1][-1]
# Out:
# False

# %%
li[-1][0]
# Out:
# 'hello'

# %%
#mutable: can add new element in list

# %%
porosity
# Out:
# [0.3, 0.41, 0.51, 0.11, 0.43, 0.67]

# %%
porosity.append(0.98)

# %%
porosity
# Out:
# [0.3, 0.41, 0.51, 0.11, 0.43, 0.67, 0.98]

# %%
a= []

# %%
a.append(32)

# %%
a
# Out:
# [32]

# %%
a.append("hello")

# %%
a
# Out:
# [32, 'hello']

# %%
a.append(True)

# %%
a
# Out:
# [32, 'hello', True]

# %%
a.pop(2)
# Out:
# True

# %%
a
# Out:
# [32, 'hello']

# %%
a.append(True)

# %%
a.append(43)

# %%
a
# Out:
# [32, 'hello', True, 43]

# %%
a.insert(2,"Jaiyesh")

# %%
a
# Out:
# [32, 'hello', 'Jaiyesh', True, 43]

# %%
a.pop(1)
# Out:
# 'hello'

# %%
a
# Out:
# [32, 'Jaiyesh', True, 43]

# %%
#List Operatuons

# %%
a = [1,2,3]
b = [5,6,7]

# %%
a+b
# Out:
# [1, 2, 3, 5, 6, 7]

# %%
a*2
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
##Numpy library: arrays

# %% [markdown]
# ## Tuples:
#
# - similar to list
# - ()
# - immutable: we can stroe passwords and other secure things

# %%
oilproduction = (2000,1500,3200,4100)

# %%
oilproduction
# Out:
# (2000, 1500, 3200, 4100)

# %%
type(oilproduction)
# Out:
# tuple

# %%
oilproduction[2]
# Out:
# 3200

# %%
oilproduction[2] = 4100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[162], line 1
# ----> 1 oilproduction[2] = 4100
#
# TypeError: 'tuple' object does not support item assignment

# %%
oilproduction[1:4:2]
# Out:
# (1500, 4100)

# %%
oilproduction.append(342)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[165], line 1
# ----> 1 oilproduction.append(342)
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## Dictionary
#
# - keys:values pair
# - {}
# - muttable

# %%
porosity = {"Panna":0.5,"Volve":0.45,"Egleford": 0.2}

# %%
porosity["Panna"]
# Out:
# 0.5

# %%
porosity["Egleford"] =0.3

# %%
porosity
# Out:
# {'Panna': 0.5, 'Volve': 0.45, 'Egleford': 0.3}

# %%
porosity["field_4"] = 0.332

# %%
porosity
# Out:
# {'Panna': 0.5, 'Volve': 0.45, 'Egleford': 0.3, 'field_4': 0.332}

# %%
porosity = {'Panna': 0.5, 'Volve': 0.45, 'Egleford': 0.3, 'field_4': 0.332,"Panna": 0.78}

# %%
porosity
# Out:
# {'Panna': 0.78, 'Volve': 0.45, 'Egleford': 0.3, 'field_4': 0.332}

# %%
d1 = {'_3443':'jc','name':'Jaiyesh','n':[2,3,4,5,67,8,'js',(1,2,3,4)],'t':(3,4,5,6),'d':{1:23,'jv':'hs'}}

# %%
d1
# Out:
# {'_3443': 'jc',
#  'name': 'Jaiyesh',
#  'n': [2, 3, 4, 5, 67, 8, 'js', (1, 2, 3, 4)],
#  't': (3, 4, 5, 6),
#  'd': {1: 23, 'jv': 'hs'}}

# %%
d1["d"]
# Out:
# {1: 23, 'jv': 'hs'}

# %%
d1["d"]["jv"]
# Out:
# 'hs'

# %%
porosity.pop("field_4")
# Out:
# 0.332

# %%
porosity
# Out:
# {'Panna': 0.78, 'Volve': 0.45, 'Egleford': 0.3}

# %%
rock_properties = {"lithology": "Limestone","porosity":0.43,"permeability": 23}

# %%
rock_properties
# Out:
# {'lithology': 'Limestone', 'porosity': 0.43, 'permeability': 23}

# %%
rock_properties["Water Saturation"] = 0.21

# %%
rock_properties
# Out:
# {'lithology': 'Limestone',
#  'porosity': 0.43,
#  'permeability': 23,
#  'Water Saturation': 0.21}

# %% [markdown]
# ## Sets
# - {}
# - duplication is not allowed in sets
# - indexing doesnt work

# %%
perm = {23,4535,232,54,6,34,36,564,343,343,23,23,23,23,23,23,23,23,343,232,232,54,"hello"}

# %%
perm
# Out:
# {23, 232, 34, 343, 36, 4535, 54, 564, 6, 'hello'}

# %%
perm[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[191], line 1
# ----> 1 perm[0]
#
# TypeError: 'set' object is not subscriptable

# %%
perm_list = list(perm)

# %%
perm_list[0]
# Out:
# 34

# %% [markdown]
# ## Summary of Data Structures
#
# 1. List: muttable,[], empty list are used heavily to populate it later
# 2. Tuples: Immutabe,(), data cannot be changed
# 3. Dictionary: {}, muttable, key:value
# 4. Sets: {}, no duplication
